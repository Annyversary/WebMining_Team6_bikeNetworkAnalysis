# %% [markdown]
# ## Note on the GML File and Network Modeling
#
# Our quarterly GML datasets are not GML files in the traditional sense of the **Graph Modelling Language** as expected by `networkx.read_gml()`. Instead, they use the **Geographic Markup Language (GML)** – an XML-based format for representing geographical features such as lines, points, and polygons.
#
# While `networkx.read_gml()` expects a GML file structured as a graph with named nodes and edges, the dataset in question contains georeferenced lines in the form of `LineString` geometries. These lines represent bicycle paths defined by their coordinates but do not explicitly define a network with uniquely labeled nodes and directed edges.
#
#
# To build a `networkx`-compatible network from this file, the following steps were required:
#
# 1. **Load the file using `geopandas`**: The geographic GML format can be read directly with GeoPandas.
# 2. **Extract geometries**: The geometries in the file represent paths, and each geometry can be used to define edges in the network.
# 3. **Determine the start and end points** of each line: These serve as nodes in the graph.
# 4. **Create a directed graph with `networkx`**: Each line (edge) can be enriched with attributes like `TRACKS_FWD`, `TRACKS_BAC`, `SPEED_REL`, `YEAR`, and `MONTH`. The forward (`TRACKS_FWD`) and backward (`TRACKS_BAC`) edges are stored separately, allowing for directional analysis of the paths.
#
# These steps make it possible to transform geospatial data into a network structure suitable for advanced analysis such as **centrality measures**, **clustering**, or **prediction tasks**.
#
# To install the required libraries, use the following command:
# ```bash
# pip install geopandas networkx shapely

# %%
import geopandas as gpd
import networkx as nx
import os

def create_bike_network(file_path, month, year):
    """
    Creates a directed bike network graph from the provided GML file, 
    filtered by the specified month and year. The graph is then saved 
    as a GraphML file.

    Parameters:
    file_path (str): The file path to the GML file containing the bike network data.
    month (int): The month to filter the data.
    year (int): The year to filter the data.
    """
    
    # 1. Load the GML file
    gdf = gpd.read_file(file_path)

    # 2. Initialize the network (directed graph)
    G = nx.DiGraph()

    # 3. Iterate over each row in the GeoDataFrame
    for idx, row in gdf.iterrows():
        # Only process rows with the specified month and year
        if row.get('MONTH') != month or row.get('YEAR') != year:
            continue

        # Get the geometry of the row
        geom = row.geometry

        # Process each line in the geometry (in case of multiple geometries in a row)
        for line in geom.geoms:
            coords = list(line.coords)
            # Round the coordinates to 3 decimal places
            coords_rounded = [(round(x, 3), round(y, 3)) for x, y in coords]

            start = tuple(coords_rounded[0])
            end = tuple(coords_rounded[-1])

            # Skip if the start and end points are the same (no edge)
            if start == end:
                continue

            # Add the start and end nodes if they don't already exist in the graph
            if not G.has_node(start):
                G.add_node(start)
            if not G.has_node(end):
                G.add_node(end)

            # Add or update the forward edge (tracks_fwd)
            if G.has_edge(start, end) and 'tracks_fwd' in G[start][end]:
                G[start][end]['tracks_fwd'] += row.get('TRACKS_FWD', 0)
            elif G.has_edge(start, end) and 'tracks_bac' in G[start][end]:
                G[start][end]['tracks_bac'] += row.get('TRACKS_BAC', 0)
            else:
                # Create the forward edge if it doesn't exist
                G.add_edge(
                    start, end,
                    id=row.get('ID'),
                    tracks_fwd=row.get('TRACKS_FWD'),
                    year=row.get('YEAR'),
                    month=row.get('MONTH'),
                    speed_rel=row.get('SPEED_REL')
                )

            # Add or update the backward edge (tracks_bac)
            if G.has_edge(end, start) and 'tracks_bac' in G[end][start]:
                G[end][start]['tracks_bac'] += row.get('TRACKS_FWD', 0)
            elif G.has_edge(end, start) and 'tracks_fwd' in G[end][start]:
                G[end][start]['tracks_fwd'] += row.get('TRACKS_BAC', 0)
            else:
                # Create the backward edge if it doesn't exist
                G.add_edge(
                    end, start,
                    id=row.get('ID'),
                    tracks_bac=row.get('TRACKS_BAC'),
                    year=row.get('YEAR'),
                    month=row.get('MONTH'),
                    speed_rel=row.get('SPEED_REL')
                )
     

    # 4. Print the number of nodes and edges in the graph
    print(f"Nodes: {len(G.nodes)}, Edges: {len(G.edges)}")
    print("First 5 nodes:", list(G.nodes)[:5])
    print("First 5 edges:", list(G.edges(data=True))[:5])

    # 5. Save the network as a GraphML file
    output_dir = os.path.join('..', 'graphs', str(year))
    os.makedirs(output_dir, exist_ok=True)  # Stelle sicher, dass das Verzeichnis existiert
    output_path = os.path.join(output_dir, f"bike_network_{year}_{month}.graphml")

    # 6. Save the graph in GraphML format
    nx.write_graphml(G, output_path)

    print(f"Graph saved at: {output_path}")

# %% [markdown]
# ## Generating Bike Network Graphs for Each Year and Quarter
#
# The function `generate_networks()` automates the process of generating bike network graphs for each month in the years 2021 through 2024. The function iterates over all quarters and months within each year and processes the corresponding GML files for each quarter.

# %%
def generate_networks():
    # Years from 2021 to 2024
    years = range(2021, 2025)
    
    # Quarters and months
    quarters = {
        "Q1": range(0, 3),   # January to March
        "Q2": range(3, 6),   # April to June
        "Q3": range(6, 9),   # July to September
        "Q4": range(9, 12)   # October to December
    }
    
    # Loop through each year and each quarter, then each month
    for year in years:
        for quarter, months in quarters.items():
            for month in months:
                # Create the file path based on the schema
                file_path = os.path.join("..", "data", str(year), f"bike_citizens_rh_{quarter}_{year}.gml")
                
                # Check if the file exists
                if os.path.exists(file_path):
                    print(f"Processing file: {file_path} (Year: {year}, Quarter: {quarter}, Month: {month})")
                    create_bike_network(file_path, month, year)
                else:
                    print(f"File not found: {file_path} (Year: {year}, Quarter: {quarter}, Month: {month})")

# Example call of the script
generate_networks()
# Out:
# Processing file: ..\data\2021\bike_citizens_rh_Q1_2021.gml (Year: 2021, Quarter: Q1, Month: 0)
# Nodes: 7061, Edges: 16190
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 78, 'year': 2021, 'month': 0, 'speed_rel': 0.8453424565}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 99, 'year': 2021, 'month': 0, 'speed_rel': 0.9411203871}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 9, 'year': 2021, 'month': 0, 'speed_rel': 0.6649648386}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 28, 'year': 2021, 'month': 0, 'speed_rel': 0.794345224}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 95, 'year': 2021, 'month': 0, 'speed_rel': 0.8453424565})]
# Graph saved at: ..\graphs\2021\bike_network_2021_0.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q1_2021.gml (Year: 2021, Quarter: Q1, Month: 1)
# Nodes: 8807, Edges: 19948
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 91, 'year': 2021, 'month': 1, 'speed_rel': 0.8453424565}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 96, 'year': 2021, 'month': 1, 'speed_rel': 0.9411203871}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 7, 'year': 2021, 'month': 1, 'speed_rel': 0.6649648386}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 26, 'year': 2021, 'month': 1, 'speed_rel': 0.794345224}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 91, 'year': 2021, 'month': 1, 'speed_rel': 0.8453424565})]
# Graph saved at: ..\graphs\2021\bike_network_2021_1.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q1_2021.gml (Year: 2021, Quarter: Q1, Month: 2)
# Nodes: 10794, Edges: 24880
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.377), (9.706, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 118, 'year': 2021, 'month': 2, 'speed_rel': 0.8453424565}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 132, 'year': 2021, 'month': 2, 'speed_rel': 0.9411203871}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 6, 'year': 2021, 'month': 2, 'speed_rel': 0.6649648386}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 40, 'year': 2021, 'month': 2, 'speed_rel': 0.794345224}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 117, 'year': 2021, 'month': 2, 'speed_rel': 0.8453424565})]
# Graph saved at: ..\graphs\2021\bike_network_2021_2.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q2_2021.gml (Year: 2021, Quarter: Q2, Month: 3)
# Nodes: 11260, Edges: 25670
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.377), (9.706, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 116, 'year': 2021, 'month': 3, 'speed_rel': 0.8479774258}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 143, 'year': 2021, 'month': 3, 'speed_rel': 0.9440109242}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 6, 'year': 2021, 'month': 3, 'speed_rel': 0.6684176758}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 31, 'year': 2021, 'month': 3, 'speed_rel': 0.8093913909}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 126, 'year': 2021, 'month': 3, 'speed_rel': 0.8479774258})]
# Graph saved at: ..\graphs\2021\bike_network_2021_3.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q2_2021.gml (Year: 2021, Quarter: Q2, Month: 4)
# Nodes: 16738, Edges: 39098
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 3, 'year': 2021, 'month': 4, 'speed_rel': 0.8556523691}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 1, 'year': 2021, 'month': 4, 'speed_rel': 0.8556523691}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 198, 'year': 2021, 'month': 4, 'speed_rel': 0.8479774258}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 219, 'year': 2021, 'month': 4, 'speed_rel': 0.9440109242}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 6, 'year': 2021, 'month': 4, 'speed_rel': 0.6684176758})]
# Graph saved at: ..\graphs\2021\bike_network_2021_4.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q2_2021.gml (Year: 2021, Quarter: Q2, Month: 5)
# Nodes: 19945, Edges: 47910
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 302, 'year': 2021, 'month': 5, 'speed_rel': 0.8479774258}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 377, 'year': 2021, 'month': 5, 'speed_rel': 0.9440109242}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 32, 'year': 2021, 'month': 5, 'speed_rel': 0.6684176758}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 151, 'year': 2021, 'month': 5, 'speed_rel': 0.8093913909}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 322, 'year': 2021, 'month': 5, 'speed_rel': 0.8479774258})]
# Graph saved at: ..\graphs\2021\bike_network_2021_5.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q3_2021.gml (Year: 2021, Quarter: Q3, Month: 6)
# Nodes: 17082, Edges: 40926
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 302, 'year': 2021, 'month': 6, 'speed_rel': 0.8574304661}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 321, 'year': 2021, 'month': 6, 'speed_rel': 0.9519029113}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 21, 'year': 2021, 'month': 6, 'speed_rel': 0.6453721245}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 117, 'year': 2021, 'month': 6, 'speed_rel': 0.8169748329}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 269, 'year': 2021, 'month': 6, 'speed_rel': 0.8574304661})]
# Graph saved at: ..\graphs\2021\bike_network_2021_6.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q3_2021.gml (Year: 2021, Quarter: Q3, Month: 7)
# Nodes: 16315, Edges: 38644
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 307, 'year': 2021, 'month': 7, 'speed_rel': 0.8574304661}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 266, 'year': 2021, 'month': 7, 'speed_rel': 0.9519029113}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 12, 'year': 2021, 'month': 7, 'speed_rel': 0.6453721245}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 100, 'year': 2021, 'month': 7, 'speed_rel': 0.8169748329}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 241, 'year': 2021, 'month': 7, 'speed_rel': 0.8574304661})]
# Graph saved at: ..\graphs\2021\bike_network_2021_7.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q3_2021.gml (Year: 2021, Quarter: Q3, Month: 8)
# Nodes: 16106, Edges: 38378
# First 5 nodes: [(9.894, 52.348), (9.895, 52.349), (9.896, 52.349), (9.717, 52.373), (9.715, 52.375)]
# First 5 edges: [((9.894, 52.348), (9.895, 52.349), {'id': 48, 'tracks_fwd': 0, 'year': 2021, 'month': 8, 'speed_rel': 0.7715546471}), ((9.894, 52.348), (9.894, 52.349), {'id': 130, 'tracks_bac': 5, 'year': 2021, 'month': 8, 'speed_rel': 0.7955438806}), ((9.895, 52.349), (9.894, 52.348), {'id': 48, 'tracks_bac': 4, 'year': 2021, 'month': 8, 'speed_rel': 0.7715546471}), ((9.895, 52.349), (9.896, 52.349), {'id': 49, 'tracks_fwd': 0, 'year': 2021, 'month': 8, 'speed_rel': 0.8167614911}), ((9.896, 52.349), (9.895, 52.349), {'id': 49, 'tracks_bac': 4, 'year': 2021, 'month': 8, 'speed_rel': 0.8167614911})]
# Graph saved at: ..\graphs\2021\bike_network_2021_8.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q4_2021.gml (Year: 2021, Quarter: Q4, Month: 9)
# Nodes: 11607, Edges: 27082
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 143, 'year': 2021, 'month': 9, 'speed_rel': 0.8607432595}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 143, 'year': 2021, 'month': 9, 'speed_rel': 0.9469600483}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 8, 'year': 2021, 'month': 9, 'speed_rel': 0.6980029666}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 71, 'year': 2021, 'month': 9, 'speed_rel': 0.8126546946}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 119, 'year': 2021, 'month': 9, 'speed_rel': 0.8607432595})]
# Graph saved at: ..\graphs\2021\bike_network_2021_9.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q4_2021.gml (Year: 2021, Quarter: Q4, Month: 10)
# Nodes: 9554, Edges: 22456
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.377), (9.706, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 141, 'year': 2021, 'month': 10, 'speed_rel': 0.8607432595}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 160, 'year': 2021, 'month': 10, 'speed_rel': 0.9469600483}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 10, 'year': 2021, 'month': 10, 'speed_rel': 0.6980029666}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 75, 'year': 2021, 'month': 10, 'speed_rel': 0.8126546946}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 142, 'year': 2021, 'month': 10, 'speed_rel': 0.8607432595})]
# Graph saved at: ..\graphs\2021\bike_network_2021_10.graphml
# Processing file: ..\data\2021\bike_citizens_rh_Q4_2021.gml (Year: 2021, Quarter: Q4, Month: 11)
# Nodes: 8788, Edges: 20356
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.706, 52.377), (9.707, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 91, 'year': 2021, 'month': 11, 'speed_rel': 0.8607432595}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 98, 'year': 2021, 'month': 11, 'speed_rel': 0.9469600483}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 5, 'year': 2021, 'month': 11, 'speed_rel': 0.6980029666}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 40, 'year': 2021, 'month': 11, 'speed_rel': 0.8126546946}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 95, 'year': 2021, 'month': 11, 'speed_rel': 0.8607432595})]
# Graph saved at: ..\graphs\2021\bike_network_2021_11.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q1_2022.gml (Year: 2022, Quarter: Q1, Month: 0)
# Nodes: 9227, Edges: 21472
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 92, 'year': 2022, 'month': 0, 'speed_rel': 0.8579631141}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 107, 'year': 2022, 'month': 0, 'speed_rel': 0.9366815565}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 13, 'year': 2022, 'month': 0, 'speed_rel': 0.6249631872}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 60, 'year': 2022, 'month': 0, 'speed_rel': 0.8219342523}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 96, 'year': 2022, 'month': 0, 'speed_rel': 0.8579631141})]
# Graph saved at: ..\graphs\2022\bike_network_2022_0.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q1_2022.gml (Year: 2022, Quarter: Q1, Month: 1)
# Nodes: 9213, Edges: 21276
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.706, 52.377), (9.707, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 84, 'year': 2022, 'month': 1, 'speed_rel': 0.8579631141}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 87, 'year': 2022, 'month': 1, 'speed_rel': 0.9366815565}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 25, 'year': 2022, 'month': 1, 'speed_rel': 0.6249631872}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 67, 'year': 2022, 'month': 1, 'speed_rel': 0.8219342523}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 85, 'year': 2022, 'month': 1, 'speed_rel': 0.8579631141})]
# Graph saved at: ..\graphs\2022\bike_network_2022_1.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q1_2022.gml (Year: 2022, Quarter: Q1, Month: 2)
# Nodes: 12691, Edges: 29388
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.706, 52.377), (9.707, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 173, 'year': 2022, 'month': 2, 'speed_rel': 0.8579631141}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 189, 'year': 2022, 'month': 2, 'speed_rel': 0.9366815565}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 18, 'year': 2022, 'month': 2, 'speed_rel': 0.6249631872}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 84, 'year': 2022, 'month': 2, 'speed_rel': 0.8219342523}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 161, 'year': 2022, 'month': 2, 'speed_rel': 0.8579631141})]
# Graph saved at: ..\graphs\2022\bike_network_2022_2.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q2_2022.gml (Year: 2022, Quarter: Q2, Month: 3)
# Nodes: 13373, Edges: 31538
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 5, 'year': 2022, 'month': 3, 'speed_rel': 0.8825799295}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 1, 'year': 2022, 'month': 3, 'speed_rel': 0.8991835908}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 1, 'year': 2022, 'month': 3, 'speed_rel': 0.8825799295}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 177, 'year': 2022, 'month': 3, 'speed_rel': 0.8589169757}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 208, 'year': 2022, 'month': 3, 'speed_rel': 0.9413330132})]
# Graph saved at: ..\graphs\2022\bike_network_2022_3.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q2_2022.gml (Year: 2022, Quarter: Q2, Month: 4)
# Nodes: 18250, Edges: 43818
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 9, 'year': 2022, 'month': 4, 'speed_rel': 0.8825799295}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 3, 'year': 2022, 'month': 4, 'speed_rel': 0.8991835908}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 1, 'year': 2022, 'month': 4, 'speed_rel': 0.8825799295}), ((9.842, 52.232), (9.843, 52.232), {'id': 139444, 'tracks_fwd': 6, 'year': 2022, 'month': 4, 'speed_rel': 0.4039144125}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 427, 'year': 2022, 'month': 4, 'speed_rel': 0.8589169757})]
# Graph saved at: ..\graphs\2022\bike_network_2022_4.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q2_2022.gml (Year: 2022, Quarter: Q2, Month: 5)
# Nodes: 21419, Edges: 51668
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 3, 'year': 2022, 'month': 5, 'speed_rel': 0.8825799295}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 8, 'year': 2022, 'month': 5, 'speed_rel': 0.8991835908}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 7, 'year': 2022, 'month': 5, 'speed_rel': 0.8825799295}), ((9.842, 52.232), (9.843, 52.232), {'id': 139444, 'tracks_fwd': 2, 'year': 2022, 'month': 5, 'speed_rel': 0.4039144125}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 470, 'year': 2022, 'month': 5, 'speed_rel': 0.8589169757})]
# Graph saved at: ..\graphs\2022\bike_network_2022_5.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q3_2022.gml (Year: 2022, Quarter: Q3, Month: 6)
# Nodes: 18731, Edges: 44718
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 357, 'year': 2022, 'month': 6, 'speed_rel': 0.8622950389}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 341, 'year': 2022, 'month': 6, 'speed_rel': 0.9453564751}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 38, 'year': 2022, 'month': 6, 'speed_rel': 0.6267585253}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 127, 'year': 2022, 'month': 6, 'speed_rel': 0.8283425355}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 308, 'year': 2022, 'month': 6, 'speed_rel': 0.8622950389})]
# Graph saved at: ..\graphs\2022\bike_network_2022_6.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q3_2022.gml (Year: 2022, Quarter: Q3, Month: 7)
# Nodes: 17463, Edges: 41920
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 9, 'year': 2022, 'month': 7, 'speed_rel': 0.8673552614}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 4, 'year': 2022, 'month': 7, 'speed_rel': 0.9278174889}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 4, 'year': 2022, 'month': 7, 'speed_rel': 0.8673552614}), ((9.842, 52.232), (9.843, 52.232), {'id': 139444, 'tracks_fwd': 7, 'year': 2022, 'month': 7, 'speed_rel': 0.3438580164}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 291, 'year': 2022, 'month': 7, 'speed_rel': 0.8622950389})]
# Graph saved at: ..\graphs\2022\bike_network_2022_7.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q3_2022.gml (Year: 2022, Quarter: Q3, Month: 8)
# Nodes: 15865, Edges: 38008
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.712, 52.377), (9.712, 52.376)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 268, 'year': 2022, 'month': 8, 'speed_rel': 0.8622950389}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 294, 'year': 2022, 'month': 8, 'speed_rel': 0.9453564751}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 91, 'year': 2022, 'month': 8, 'speed_rel': 0.6267585253}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 154, 'year': 2022, 'month': 8, 'speed_rel': 0.8283425355}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 253, 'year': 2022, 'month': 8, 'speed_rel': 0.8622950389})]
# Graph saved at: ..\graphs\2022\bike_network_2022_8.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q4_2022.gml (Year: 2022, Quarter: Q4, Month: 9)
# Nodes: 15263, Edges: 36036
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 3, 'year': 2022, 'month': 9, 'speed_rel': 0.8255016341}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 2, 'year': 2022, 'month': 9, 'speed_rel': 0.8705785583}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 1, 'year': 2022, 'month': 9, 'speed_rel': 0.8255016341}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 263, 'year': 2022, 'month': 9, 'speed_rel': 0.8617408531}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 257, 'year': 2022, 'month': 9, 'speed_rel': 0.9458919696})]
# Graph saved at: ..\graphs\2022\bike_network_2022_9.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q4_2022.gml (Year: 2022, Quarter: Q4, Month: 10)
# Nodes: 11588, Edges: 27446
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.706, 52.377), (9.707, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 202, 'year': 2022, 'month': 10, 'speed_rel': 0.8617408531}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 208, 'year': 2022, 'month': 10, 'speed_rel': 0.9458919696}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 62, 'year': 2022, 'month': 10, 'speed_rel': 0.6295141863}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 90, 'year': 2022, 'month': 10, 'speed_rel': 0.8245811875}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 194, 'year': 2022, 'month': 10, 'speed_rel': 0.8617408531})]
# Graph saved at: ..\graphs\2022\bike_network_2022_10.graphml
# Processing file: ..\data\2022\bike_citizens_rh_Q4_2022.gml (Year: 2022, Quarter: Q4, Month: 11)
# Nodes: 8160, Edges: 19202
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 104, 'year': 2022, 'month': 11, 'speed_rel': 0.8617408531}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 103, 'year': 2022, 'month': 11, 'speed_rel': 0.9458919696}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 30, 'year': 2022, 'month': 11, 'speed_rel': 0.6295141863}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 41, 'year': 2022, 'month': 11, 'speed_rel': 0.8245811875}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 94, 'year': 2022, 'month': 11, 'speed_rel': 0.8617408531})]
# Graph saved at: ..\graphs\2022\bike_network_2022_11.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q1_2023.gml (Year: 2023, Quarter: Q1, Month: 0)
# Nodes: 8880, Edges: 20838
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 139, 'year': 2023, 'month': 0, 'speed_rel': 0.861711873}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 138, 'year': 2023, 'month': 0, 'speed_rel': 0.9375428389}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 40, 'year': 2023, 'month': 0, 'speed_rel': 0.6240472428}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 53, 'year': 2023, 'month': 0, 'speed_rel': 0.8028987215}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 123, 'year': 2023, 'month': 0, 'speed_rel': 0.861711873})]
# Graph saved at: ..\graphs\2023\bike_network_2023_0.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q1_2023.gml (Year: 2023, Quarter: Q1, Month: 1)
# Nodes: 9559, Edges: 22474
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 136, 'year': 2023, 'month': 1, 'speed_rel': 0.861711873}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 121, 'year': 2023, 'month': 1, 'speed_rel': 0.9375428389}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 36, 'year': 2023, 'month': 1, 'speed_rel': 0.6240472428}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 50, 'year': 2023, 'month': 1, 'speed_rel': 0.8028987215}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 107, 'year': 2023, 'month': 1, 'speed_rel': 0.861711873})]
# Graph saved at: ..\graphs\2023\bike_network_2023_1.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q1_2023.gml (Year: 2023, Quarter: Q1, Month: 2)
# Nodes: 9549, Edges: 22582
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.712, 52.377), (9.712, 52.376)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 143, 'year': 2023, 'month': 2, 'speed_rel': 0.861711873}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 124, 'year': 2023, 'month': 2, 'speed_rel': 0.9375428389}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 25, 'year': 2023, 'month': 2, 'speed_rel': 0.6240472428}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 56, 'year': 2023, 'month': 2, 'speed_rel': 0.8028987215}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 117, 'year': 2023, 'month': 2, 'speed_rel': 0.861711873})]
# Graph saved at: ..\graphs\2023\bike_network_2023_2.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q2_2023.gml (Year: 2023, Quarter: Q2, Month: 3)
# Nodes: 11905, Edges: 27816
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 2, 'year': 2023, 'month': 3, 'speed_rel': 0.8447826971}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 3, 'year': 2023, 'month': 3, 'speed_rel': 0.9268163531}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 2, 'year': 2023, 'month': 3, 'speed_rel': 0.8447826971}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 218, 'year': 2023, 'month': 3, 'speed_rel': 0.867103066}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 194, 'year': 2023, 'month': 3, 'speed_rel': 0.9485604327})]
# Graph saved at: ..\graphs\2023\bike_network_2023_3.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q2_2023.gml (Year: 2023, Quarter: Q2, Month: 4)
# Nodes: 14252, Edges: 33526
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.717, 52.373), (9.715, 52.375), (9.714, 52.377)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 4, 'year': 2023, 'month': 4, 'speed_rel': 0.8447826971}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 4, 'year': 2023, 'month': 4, 'speed_rel': 0.9268163531}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 2, 'year': 2023, 'month': 4, 'speed_rel': 0.8447826971}), ((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 242, 'year': 2023, 'month': 4, 'speed_rel': 0.867103066}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 223, 'year': 2023, 'month': 4, 'speed_rel': 0.9485604327})]
# Graph saved at: ..\graphs\2023\bike_network_2023_4.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q2_2023.gml (Year: 2023, Quarter: Q2, Month: 5)
# Nodes: 19956, Edges: 48264
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.697, 52.38), (9.698, 52.38), (9.717, 52.373)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 5, 'year': 2023, 'month': 5, 'speed_rel': 0.8447826971}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 7, 'year': 2023, 'month': 5, 'speed_rel': 0.9268163531}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 2, 'year': 2023, 'month': 5, 'speed_rel': 0.8447826971}), ((9.842, 52.232), (9.843, 52.234), {'id': 61077, 'tracks_fwd': 2, 'year': 2023, 'month': 5, 'speed_rel': 0.8185703844}), ((9.697, 52.38), (9.698, 52.38), {'id': 42, 'tracks_fwd': 20, 'year': 2023, 'month': 5, 'speed_rel': 0.3629086463})]
# Graph saved at: ..\graphs\2023\bike_network_2023_5.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q3_2023.gml (Year: 2023, Quarter: Q3, Month: 6)
# Nodes: 16399, Edges: 39322
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 325, 'year': 2023, 'month': 6, 'speed_rel': 0.8678304229}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 302, 'year': 2023, 'month': 6, 'speed_rel': 0.9435045854}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 51, 'year': 2023, 'month': 6, 'speed_rel': 0.6525061066}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 94, 'year': 2023, 'month': 6, 'speed_rel': 0.8337153574}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 270, 'year': 2023, 'month': 6, 'speed_rel': 0.8678304229})]
# Graph saved at: ..\graphs\2023\bike_network_2023_6.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q3_2023.gml (Year: 2023, Quarter: Q3, Month: 7)
# Nodes: 16158, Edges: 38580
# First 5 nodes: [(9.894, 52.348), (9.895, 52.349), (9.896, 52.349), (9.897, 52.349), (9.898, 52.349)]
# First 5 edges: [((9.894, 52.348), (9.895, 52.349), {'id': 48, 'tracks_fwd': 1, 'year': 2023, 'month': 7, 'speed_rel': 0.6605246139}), ((9.894, 52.348), (9.894, 52.349), {'id': 130, 'tracks_bac': 8, 'year': 2023, 'month': 7, 'speed_rel': 0.7969564841}), ((9.894, 52.348), (9.895, 52.347), {'id': 132, 'tracks_fwd': 3, 'year': 2023, 'month': 7, 'speed_rel': 0.8027210002}), ((9.895, 52.349), (9.894, 52.348), {'id': 48, 'tracks_bac': 4, 'year': 2023, 'month': 7, 'speed_rel': 0.6605246139}), ((9.895, 52.349), (9.896, 52.349), {'id': 49, 'tracks_fwd': 1, 'year': 2023, 'month': 7, 'speed_rel': 0.7340287993})]
# Graph saved at: ..\graphs\2023\bike_network_2023_7.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q3_2023.gml (Year: 2023, Quarter: Q3, Month: 8)
# Nodes: 15919, Edges: 38494
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 314, 'year': 2023, 'month': 8, 'speed_rel': 0.8678304229}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 344, 'year': 2023, 'month': 8, 'speed_rel': 0.9435045854}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 47, 'year': 2023, 'month': 8, 'speed_rel': 0.6525061066}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 102, 'year': 2023, 'month': 8, 'speed_rel': 0.8337153574}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 325, 'year': 2023, 'month': 8, 'speed_rel': 0.8678304229})]
# Graph saved at: ..\graphs\2023\bike_network_2023_8.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q4_2023.gml (Year: 2023, Quarter: Q4, Month: 9)
# Nodes: 12994, Edges: 30948
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 197, 'year': 2023, 'month': 9, 'speed_rel': 0.8715260332}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 224, 'year': 2023, 'month': 9, 'speed_rel': 0.9470174066}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 30, 'year': 2023, 'month': 9, 'speed_rel': 0.6450716305}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 81, 'year': 2023, 'month': 9, 'speed_rel': 0.8138067143}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 212, 'year': 2023, 'month': 9, 'speed_rel': 0.8715260332})]
# Graph saved at: ..\graphs\2023\bike_network_2023_9.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q4_2023.gml (Year: 2023, Quarter: Q4, Month: 10)
# Nodes: 10201, Edges: 24346
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.712, 52.377), (9.712, 52.376)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 178, 'year': 2023, 'month': 10, 'speed_rel': 0.8715260332}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 188, 'year': 2023, 'month': 10, 'speed_rel': 0.9470174066}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 24, 'year': 2023, 'month': 10, 'speed_rel': 0.6450716305}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 79, 'year': 2023, 'month': 10, 'speed_rel': 0.8138067143}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 171, 'year': 2023, 'month': 10, 'speed_rel': 0.8715260332})]
# Graph saved at: ..\graphs\2023\bike_network_2023_10.graphml
# Processing file: ..\data\2023\bike_citizens_rh_Q4_2023.gml (Year: 2023, Quarter: Q4, Month: 11)
# Nodes: 7974, Edges: 18662
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 84, 'year': 2023, 'month': 11, 'speed_rel': 0.8715260332}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 97, 'year': 2023, 'month': 11, 'speed_rel': 0.9470174066}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 7, 'year': 2023, 'month': 11, 'speed_rel': 0.6450716305}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 29, 'year': 2023, 'month': 11, 'speed_rel': 0.8138067143}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 97, 'year': 2023, 'month': 11, 'speed_rel': 0.8715260332})]
# Graph saved at: ..\graphs\2023\bike_network_2023_11.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q1_2024.gml (Year: 2024, Quarter: Q1, Month: 0)
# Nodes: 8727, Edges: 20448
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 88, 'year': 2024, 'month': 0, 'speed_rel': 0.8627782222}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 78, 'year': 2024, 'month': 0, 'speed_rel': 0.9081267855}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 30, 'year': 2024, 'month': 0, 'speed_rel': 0.7188213304}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 52, 'year': 2024, 'month': 0, 'speed_rel': 0.8132161875}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 93, 'year': 2024, 'month': 0, 'speed_rel': 0.8627782222})]
# Graph saved at: ..\graphs\2024\bike_network_2024_0.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q1_2024.gml (Year: 2024, Quarter: Q1, Month: 1)
# Nodes: 10178, Edges: 24172
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 106, 'year': 2024, 'month': 1, 'speed_rel': 0.8627782222}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 92, 'year': 2024, 'month': 1, 'speed_rel': 0.9081267855}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 48, 'year': 2024, 'month': 1, 'speed_rel': 0.7188213304}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 76, 'year': 2024, 'month': 1, 'speed_rel': 0.8132161875}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 121, 'year': 2024, 'month': 1, 'speed_rel': 0.8627782222})]
# Graph saved at: ..\graphs\2024\bike_network_2024_1.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q1_2024.gml (Year: 2024, Quarter: Q1, Month: 2)
# Nodes: 11421, Edges: 26976
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.712, 52.377), (9.712, 52.376)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 200, 'year': 2024, 'month': 2, 'speed_rel': 0.8627782222}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 218, 'year': 2024, 'month': 2, 'speed_rel': 0.9081267855}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 25, 'year': 2024, 'month': 2, 'speed_rel': 0.7188213304}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 65, 'year': 2024, 'month': 2, 'speed_rel': 0.8132161875}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 210, 'year': 2024, 'month': 2, 'speed_rel': 0.8627782222})]
# Graph saved at: ..\graphs\2024\bike_network_2024_2.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q2_2024.gml (Year: 2024, Quarter: Q2, Month: 3)
# Nodes: 14019, Edges: 33282
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.705, 52.378), (9.705, 52.377)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 242, 'year': 2024, 'month': 3, 'speed_rel': 0.8626945323}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 250, 'year': 2024, 'month': 3, 'speed_rel': 0.9452811886}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 31, 'year': 2024, 'month': 3, 'speed_rel': 0.7079353515}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 83, 'year': 2024, 'month': 3, 'speed_rel': 0.8035083997}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 244, 'year': 2024, 'month': 3, 'speed_rel': 0.8626945323})]
# Graph saved at: ..\graphs\2024\bike_network_2024_3.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q2_2024.gml (Year: 2024, Quarter: Q2, Month: 4)
# Nodes: 18128, Edges: 43710
# First 5 nodes: [(9.837, 52.232), (9.842, 52.232), (9.697, 52.38), (9.698, 52.38), (9.717, 52.373)]
# First 5 edges: [((9.837, 52.232), (9.842, 52.232), {'id': 17, 'tracks_fwd': 4, 'year': 2024, 'month': 4, 'speed_rel': 0.8994288264}), ((9.837, 52.232), (9.833, 52.233), {'id': 1526, 'tracks_bac': 2, 'year': 2024, 'month': 4, 'speed_rel': 0.9412983162}), ((9.842, 52.232), (9.837, 52.232), {'id': 17, 'tracks_bac': 2, 'year': 2024, 'month': 4, 'speed_rel': 0.8994288264}), ((9.697, 52.38), (9.698, 52.38), {'id': 42, 'tracks_fwd': 13, 'year': 2024, 'month': 4, 'speed_rel': 0.2380534734}), ((9.697, 52.38), (9.697, 52.379), {'id': 2593, 'tracks_bac': 0, 'year': 2024, 'month': 4, 'speed_rel': 0.0587954398})]
# Graph saved at: ..\graphs\2024\bike_network_2024_4.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q2_2024.gml (Year: 2024, Quarter: Q2, Month: 5)
# Nodes: 18302, Edges: 44244
# First 5 nodes: [(9.717, 52.373), (9.715, 52.375), (9.714, 52.377), (9.712, 52.377), (9.712, 52.376)]
# First 5 edges: [((9.717, 52.373), (9.715, 52.375), {'id': 85, 'tracks_fwd': 440, 'year': 2024, 'month': 5, 'speed_rel': 0.8626945323}), ((9.717, 52.373), (9.718, 52.372), {'id': 7849, 'tracks_bac': 416, 'year': 2024, 'month': 5, 'speed_rel': 0.9452811886}), ((9.717, 52.373), (9.718, 52.374), {'id': 30249, 'tracks_fwd': 44, 'year': 2024, 'month': 5, 'speed_rel': 0.7079353515}), ((9.717, 52.373), (9.716, 52.373), {'id': 42548, 'tracks_fwd': 144, 'year': 2024, 'month': 5, 'speed_rel': 0.8035083997}), ((9.715, 52.375), (9.717, 52.373), {'id': 85, 'tracks_bac': 400, 'year': 2024, 'month': 5, 'speed_rel': 0.8626945323})]
# Graph saved at: ..\graphs\2024\bike_network_2024_5.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q3_2024.gml (Year: 2024, Quarter: Q3, Month: 6)
# Nodes: 17204, Edges: 41008
# First 5 nodes: [(9.837, 52.232), (9.838, 52.232), (9.839, 52.232), (9.84, 52.232), (9.842, 52.232)]
# First 5 edges: [((9.837, 52.232), (9.838, 52.232), {'id': 37, 'tracks_fwd': 3, 'year': 2024, 'month': 6, 'speed_rel': 0.9315378075}), ((9.837, 52.232), (9.833, 52.233), {'id': 1987, 'tracks_bac': 4, 'year': 2024, 'month': 6, 'speed_rel': 0.930466465}), ((9.838, 52.232), (9.837, 52.232), {'id': 37, 'tracks_bac': 4, 'year': 2024, 'month': 6, 'speed_rel': 0.9315378075}), ((9.838, 52.232), (9.839, 52.232), {'id': 38, 'tracks_fwd': 3, 'year': 2024, 'month': 6, 'speed_rel': 0.9479212469}), ((9.839, 52.232), (9.838, 52.232), {'id': 38, 'tracks_bac': 4, 'year': 2024, 'month': 6, 'speed_rel': 0.9479212469})]
# Graph saved at: ..\graphs\2024\bike_network_2024_6.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q3_2024.gml (Year: 2024, Quarter: Q3, Month: 7)
# Nodes: 17287, Edges: 41488
# First 5 nodes: [(9.837, 52.232), (9.838, 52.232), (9.839, 52.232), (9.84, 52.232), (9.842, 52.232)]
# First 5 edges: [((9.837, 52.232), (9.838, 52.232), {'id': 37, 'tracks_fwd': 5, 'year': 2024, 'month': 7, 'speed_rel': 0.9315378075}), ((9.837, 52.232), (9.833, 52.233), {'id': 1987, 'tracks_bac': 1, 'year': 2024, 'month': 7, 'speed_rel': 0.930466465}), ((9.838, 52.232), (9.837, 52.232), {'id': 37, 'tracks_bac': 1, 'year': 2024, 'month': 7, 'speed_rel': 0.9315378075}), ((9.838, 52.232), (9.839, 52.232), {'id': 38, 'tracks_fwd': 5, 'year': 2024, 'month': 7, 'speed_rel': 0.9479212469}), ((9.839, 52.232), (9.838, 52.232), {'id': 38, 'tracks_bac': 1, 'year': 2024, 'month': 7, 'speed_rel': 0.9479212469})]
# Graph saved at: ..\graphs\2024\bike_network_2024_7.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q3_2024.gml (Year: 2024, Quarter: Q3, Month: 8)
# Nodes: 15685, Edges: 37558
# First 5 nodes: [(9.705, 52.378), (9.705, 52.377), (9.706, 52.377), (9.707, 52.377), (9.717, 52.373)]
# First 5 edges: [((9.705, 52.378), (9.705, 52.377), {'id': 51, 'tracks_fwd': 28, 'year': 2024, 'month': 8, 'speed_rel': 0.7307283174}), ((9.705, 52.378), (9.703, 52.378), {'id': 10351, 'tracks_bac': 11, 'year': 2024, 'month': 8, 'speed_rel': 0.8027753885}), ((9.705, 52.377), (9.705, 52.378), {'id': 51, 'tracks_bac': 39, 'year': 2024, 'month': 8, 'speed_rel': 0.7307283174}), ((9.705, 52.377), (9.706, 52.377), {'id': 52, 'tracks_fwd': 14, 'year': 2024, 'month': 8, 'speed_rel': 0.7989026714}), ((9.705, 52.377), (9.704, 52.376), {'id': 9536, 'tracks_bac': 15, 'year': 2024, 'month': 8, 'speed_rel': 0.7915072074})]
# Graph saved at: ..\graphs\2024\bike_network_2024_8.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q4_2024.gml (Year: 2024, Quarter: Q4, Month: 9)
# Nodes: 13136, Edges: 31316
# First 5 nodes: [(9.837, 52.232), (9.838, 52.232), (9.839, 52.232), (9.84, 52.232), (9.842, 52.232)]
# First 5 edges: [((9.837, 52.232), (9.838, 52.232), {'id': 37, 'tracks_fwd': 2, 'year': 2024, 'month': 9, 'speed_rel': 0.8867511823}), ((9.837, 52.232), (9.834, 52.225), {'id': 3126, 'tracks_bac': 2, 'year': 2024, 'month': 9, 'speed_rel': 0.9752116195}), ((9.838, 52.232), (9.837, 52.232), {'id': 37, 'tracks_bac': 2, 'year': 2024, 'month': 9, 'speed_rel': 0.8867511823}), ((9.838, 52.232), (9.839, 52.232), {'id': 38, 'tracks_fwd': 2, 'year': 2024, 'month': 9, 'speed_rel': 0.9597638604}), ((9.839, 52.232), (9.838, 52.232), {'id': 38, 'tracks_bac': 2, 'year': 2024, 'month': 9, 'speed_rel': 0.9597638604})]
# Graph saved at: ..\graphs\2024\bike_network_2024_9.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q4_2024.gml (Year: 2024, Quarter: Q4, Month: 10)
# Nodes: 10587, Edges: 25064
# First 5 nodes: [(9.705, 52.378), (9.705, 52.377), (9.706, 52.377), (9.707, 52.377), (9.717, 52.373)]
# First 5 edges: [((9.705, 52.378), (9.705, 52.377), {'id': 51, 'tracks_fwd': 32, 'year': 2024, 'month': 10, 'speed_rel': 0.6788896871}), ((9.705, 52.378), (9.703, 52.378), {'id': 10351, 'tracks_bac': 10, 'year': 2024, 'month': 10, 'speed_rel': 0.8126840293}), ((9.705, 52.377), (9.705, 52.378), {'id': 51, 'tracks_bac': 55, 'year': 2024, 'month': 10, 'speed_rel': 0.6788896871}), ((9.705, 52.377), (9.706, 52.377), {'id': 52, 'tracks_fwd': 10, 'year': 2024, 'month': 10, 'speed_rel': 0.7623391733}), ((9.705, 52.377), (9.704, 52.376), {'id': 9536, 'tracks_bac': 19, 'year': 2024, 'month': 10, 'speed_rel': 0.8329798774})]
# Graph saved at: ..\graphs\2024\bike_network_2024_10.graphml
# Processing file: ..\data\2024\bike_citizens_rh_Q4_2024.gml (Year: 2024, Quarter: Q4, Month: 11)
# Nodes: 8925, Edges: 21094
# First 5 nodes: [(9.705, 52.378), (9.705, 52.377), (9.706, 52.377), (9.707, 52.377), (9.717, 52.373)]
# First 5 edges: [((9.705, 52.378), (9.705, 52.377), {'id': 51, 'tracks_fwd': 15, 'year': 2024, 'month': 11, 'speed_rel': 0.6788896871}), ((9.705, 52.378), (9.703, 52.378), {'id': 10351, 'tracks_bac': 12, 'year': 2024, 'month': 11, 'speed_rel': 0.8126840293}), ((9.705, 52.377), (9.705, 52.378), {'id': 51, 'tracks_bac': 20, 'year': 2024, 'month': 11, 'speed_rel': 0.6788896871}), ((9.705, 52.377), (9.706, 52.377), {'id': 52, 'tracks_fwd': 9, 'year': 2024, 'month': 11, 'speed_rel': 0.7623391733}), ((9.705, 52.377), (9.704, 52.376), {'id': 9536, 'tracks_bac': 6, 'year': 2024, 'month': 11, 'speed_rel': 0.8329798774})]
# Graph saved at: ..\graphs\2024\bike_network_2024_11.graphml
